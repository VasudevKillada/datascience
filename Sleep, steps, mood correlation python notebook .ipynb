# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
df = pd.read_csv('25.csv')

# %%
df.head()
# Out:
#          date  step_count  mood  calories_burned  hours_of_sleep  \
# 0  2017-10-06        5464   200              181               5
# 1  2017-10-07        6041   100              197               8
# 2  2017-10-08          25   100                0               5
# 3  2017-10-09        5461   100              174               4
# 4  2017-10-10        6915   200              223               5
#
#    bool_of_active  weight_kg
# 0               0         66
# 1               0         66
# 2               0         66
# 3               0         66
# 4             500         66

# %%
plt.figure(figsize=(5,5))
sns.heatmap(df.corr(), annot=True, annot_kws={"size":9})

# %%
df.columns
# Out:
# Index(['date', 'step_count', 'mood', 'calories_burned', 'hours_of_sleep',
#        'bool_of_active', 'weight_kg'],
#       dtype='object')

# %%
sns.jointplot(df.calories_burned, df.step_count, kind = "scatter")   
plt.show()

#Joint scatter plot with least square line
sns.jointplot(df.calories_burned, df.step_count, kind = "reg")    
plt.show()

# %%
total_records= len(df)


columns = ["hours_of_sleep","mood"]
for i in columns:

    ax1 = sns.countplot(data=df,x= i,hue="bool_of_active")
    plt.show()
df
# Out:
#           date  step_count  mood  calories_burned  hours_of_sleep  \
# 0   2017-10-06        5464   200              181               5
# 1   2017-10-07        6041   100              197               8
# 2   2017-10-08          25   100                0               5
# 3   2017-10-09        5461   100              174               4
# 4   2017-10-10        6915   200              223               5
# ..         ...         ...   ...              ...             ...
# 91  2018-01-05         133   100                4               2
# 92  2018-01-06         153   300                0               8
# 93  2018-01-07         500   200                0               5
# 94  2018-01-08        2127   200                0               5
# 95  2018-01-09        2203   300                0               5
#
#     bool_of_active  weight_kg
# 0                0         66
# 1                0         66
# 2                0         66
# 3                0         66
# ...
